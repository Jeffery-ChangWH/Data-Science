# %%
# %matplotlib inline

# %% [markdown]
# # %matplotlib inline 這個魔術命令，則需使用 plt.show() 才能顯示圖形。

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(10)
plt.plot(x)

# %%
plt.plot()
# Shift+Tab
# plt.plot ?

# %%
x = np.random.rand(10, 2)
plt.plot(x)
# Out:
# [<matplotlib.lines.Line2D at 0x17d2ad30ba8>,
#  <matplotlib.lines.Line2D at 0x17d2ad30cf8>]

# %%
x = np.random.rand(10, 2)
plt.plot(x)

# 畫點
i=3
plt.plot(i, x[i, 0], 'r^')

# 畫線 plt.plot([x1, x2], [y1, y2])
j=7
plt.plot([i, j], [x[i, 0], x[j, 0]], 'k-')

# %%
from matplotlib.font_manager import FontProperties
font = FontProperties(fname=r"c:\windows\fonts\simsun.ttc", size=14)

x = np.arange(10)
plt.plot(x)
plt.title('中文測試', fontproperties=font)
# Out:
# Text(0.5, 1.0, '中文測試')

# %%
fig = plt.figure()
ax1 = fig.add_axes([0, 0, 1, 1])
x = np.random.randn(1000)
ax1.hist(x)
ax2 = fig.add_axes([0.07, 0.65, 0.3, 0.3])
ax2.plot(x)
